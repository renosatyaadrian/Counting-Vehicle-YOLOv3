# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My\ Drive/Skripsi/yolov3-master
# Out:
# /content/gdrive/My Drive/Skripsi/yolov3-master

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9624456646321220749, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 2207652070678926340
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 1530447231413592524
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 15938776971261743387
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
# !python train.py --data data/coco16.data --cfg cfg/yolov3.cfg --weight weights/yolov3.weights --device 0 --epoch 10 --batch-size 16
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='cfg/yolov3.cfg', data='data/coco16.data', device='0', epochs=10, evolve=False, img_size=[320, 640], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# 2020-05-13 01:38:04.676980: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 222 layers, 6.19491e+07 parameters, 6.19491e+07 gradients
# Optimizer groups: 75 .bias, 75 Conv2d.weight, 72 other
# Caching labels (45 found, 0 missing, 0 empty, 0 duplicate, for 45 images): 100% 45/45 [00:29<00:00,  1.54it/s]
# ...

# %%
# !python -c 'from models import *; convert("cfg/yolov3.cfg", "weights/best.pt")'
# Out:
# Model Summary: 222 layers, 6.19491e+07 parameters, 6.19491e+07 gradients
# Success: converted 'weights/best.pt' to 'converted.weights'

# %%
# %cd /content/gdrive/My\ Drive/Skripsi/Fix/
# Out:
# /content/gdrive/My Drive/Skripsi/Fix

# %% [markdown]
# !python YOLOv3.py --input videos/plengkunggading2.mp4 --output output/PL2-new.avi --yolo yolo-coco/

# %%
# !python YOLOv3.py --input videos/plengkunggading2.mp4 --output output/PL2-new.avi --yolo yolo-coco/
# Out:
# [INFO] loading YOLO from disk...
# [INFO] 7 total frames in video
# Total vehicles in image 20
# Each vehicles count in image {'car': 11, 'motorbike': 9}
# [INFO] single frame took 2.7168 seconds
# [INFO] estimated total time to finish: 19.0175
# Total vehicles in image 20
# Each vehicles count in image {'car': 11, 'motorbike': 9}
# Total vehicles in image 21
# Each vehicles count in image {'car': 12, 'motorbike': 9}
# Total vehicles in image 19
# Each vehicles count in image {'car': 11, 'motorbike': 8}
# Total vehicles in image 20
# Each vehicles count in image {'car': 11, 'motorbike': 9}
# Total vehicles in image 20
# Each vehicles count in image {'car': 11, 'motorbike': 9}
# Traceback (most recent call last):
#   File "YOLOv3.py", line 112, in <module>
#     layerOutputs = net.forward(ln)
# KeyboardInterrupt

# %%
# %cd /content/gdrive/My\ Drive/Colab\ Notebooks/
# Out:
# /content/gdrive/My Drive/Colab Notebooks
